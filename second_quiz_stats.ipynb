# %% [markdown]
# # Notebook for visualizing quiz results (2/3/20)
# ## second recitation, Intro to Neuroscience Spring 2020

# %%
import pandas as pd
import seaborn as sns
import matplotlib
import numpy as np

# %% [markdown]
# ### Create pandas dataframe with column names for quiz data

# %%
file = '/Users/maltegueth/Documents/quiz_scores2.csv'
columns = ['student', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6']
data = pd.read_csv(file, sep=',', names=columns)

# %% [markdown]
# ### The correct key is: c d b c d a or 3 4 2 3 4 1

# %%
data
# Out:
#     student  Q1  Q2  Q3  Q4  Q5  Q6
# 0         1   1   4   2   3   4   1
# 1         2   1   4   2   4   4   3
# 2         3   1   4   2   3   4   3
# 3         4   1   4   2   3   2   3
# 4         5   2   4   2   1   4   1
# 5         6   1   4   2   3   4   1
# 6         7   1   4   2   3   2   4
# 7         8   2   1   3   3   2   1
# 8         9   1   3   1   1   4   3
# 9        10   3   2   2   1   4   1
# 10       11   3   4   2   3   4   1
# 11       12   3   1   3   1   4   1
# 12       13   1   1   2   3   4   3
# 13       14   1   4   2   1   2   2
# 14       15   2   4   2   3   3   3
# 15       16   1   1   2   3   3   4
# 16       17   1   1   2   3   4   1
# 17       18   2   4   2   3   4   3
# 18       19   2   4   2   3   1   3
# 19       20   1   4   2   4   2   2
# 20       21   1   4   2   3   3   2
# 21       22   3   1   3   4   4   1
# 22       23   1   4   2   4   2   1
# 23       24   3   4   2   3   4   1
# 24       25   1   1   3   3   4   1
# ...

# %% [markdown]
# ### As a reminder, here are the questions

# %% [markdown]
#     Quiz
#
#     2/3
#     Neurophysiology
#
#     Please circle the correct answer for each question. You can only pick one option per question.
#
#     The Resting Membrane Potential...
#     a) … can be formally defined as a voltage difference between compartments within the cell.
#     b) … is driven by an equal distribution of ions inside and outside of the cell, specifically K+ and Na+.
#     c) … is influenced by Na+K+ATPase.
#     d) … ranges between -10 and 10 mV.
#
#     Which of the following statements about ions is false:
#     a) K+ ions leaving the cell will make the inside of the cell more hyperpolarized.
#     b) There is a high concentration of Na+ ions outside of the cell and a high concentration of K+ ions outside of it.
#     c) The membrane at rest is not permeable to Ca++ or Na+ ions.
#     d) At rest, the concentration gradient will drive K+ ions into the cell.
#
#     Which is the correct order of phases during an action potential?
#     a) The membrane hyperpolarizes above threshold, K+ channels and Na+ channels open, K+ and Na+ channels close.
#     b) The membrane depolarizes above threshold, Na+ channels open, K+ channels open and Na+ channels begin to close, K+ ions leave the cell.
#     c) The membrane depolarizes above threshold, Na+ channels open, Na+ channels close.
#     d) K+ ions rush out, Na+ channels open, the membrane depolarizes above
#     threshold, K+ ions rush in.
#
#     The lipid bilayer consists of ...
#     a) … proteins and lipids with hydrophilic heads which point towards the inside of the membrane.
#     b) … astrocytes and glial myelin sheaths.
#     c) … a double layer of lipids with a hydrophobic and a hydrophilic part.
#     d) … proteins and lipids facing the extracellular fluid with their non-polar end.
#
#     Which of the following statements about saltatory conduction is false:
#     a) Saltatory conduction speeds up the rate of action potential conduction.
#     b) Insulation from myelin sheaths forces the depolarization to spread farther in the axon until the next Node of Ranvier.
#     c) A completely myelinated axon without Nodes of Ranvier would not support saltatory conduction because axon segments could not be depolarized.
#     d) Saltatory conduction serves to sum up action potentials at the
#     synapse.
#
#     The sodium-potassium pump is essential for transporting ions. By providing this function, the pump ...
#     a) … helps to maintain the resting membrane potential.
#     b) … is solely responsible for the resting membrane potential.
#     c) … transports ions with their concentration gradient.
#     d) … produces ATP for the cell.

# %% [markdown]
# ### Calculate the scores and convert them to percentages

# %%
key = [3, 4, 2, 3, 4, 1]
corrects = pd.DataFrame(0, index=np.arange(len(data)), columns=['score'])

for student in range(0,len(data.index)):
    corrects.loc[student,:] = len([i for i, j in zip(key, data.loc[student, "Q1":"Q6"]) if i == j])


data.insert(7, "score", corrects['score'], True)
data.insert(8, "score_percent", corrects['score']/6, True)

data
# Out:
#     student  Q1  Q2  Q3  Q4  Q5  Q6  score  score_percent
# 0         1   1   4   2   3   4   1      5       0.833333
# 1         2   1   4   2   4   4   3      3       0.500000
# 2         3   1   4   2   3   4   3      4       0.666667
# 3         4   1   4   2   3   2   3      3       0.500000
# 4         5   2   4   2   1   4   1      4       0.666667
# 5         6   1   4   2   3   4   1      5       0.833333
# 6         7   1   4   2   3   2   4      3       0.500000
# 7         8   2   1   3   3   2   1      2       0.333333
# 8         9   1   3   1   1   4   3      1       0.166667
# 9        10   3   2   2   1   4   1      4       0.666667
# 10       11   3   4   2   3   4   1      6       1.000000
# 11       12   3   1   3   1   4   1      3       0.500000
# 12       13   1   1   2   3   4   3      3       0.500000
# 13       14   1   4   2   1   2   2      2       0.333333
# 14       15   2   4   2   3   3   3      3       0.500000
# ...

# %% [markdown]
# ## Here are some basic stats from the dataframe (mean, median, sd)

# %%
data.score.mean()
# Out:
# 3.3823529411764706

# %%
data.score.median()
# Out:
# 3.0

# %%
data.score.std()
# Out:
# 1.3710139110837012

# %% [markdown]
# ## Next, check some distributional plots to visualize how the class as a whole scored

# %%
font = {'family' : 'Sans',
        'weight' : 'normal',
        'size'   : 18}

matplotlib.rc('font', **font)

# %%
fig1, axes = matplotlib.pyplot.subplots(2, 2, figsize=(7, 7), sharex=True)

ax = sns.distplot(data['score_percent']*100, kde=False, color="b", ax=axes[0,0])
sns.distplot(data['score_percent']*100, hist=False, rug=True, color="r", ax=axes[0, 1])
sns.distplot(data['score_percent']*100, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])
sns.distplot(data['score_percent']*100, color="m", ax=axes[1, 1])

ax.set(ylabel='students')
matplotlib.pyplot.tight_layout()

# %%
fig2, axes = matplotlib.pyplot.subplots(figsize=(14, 6), sharex=True)

ax = sns.violinplot(data=data.loc[:, "Q1":"Q6"], palette="Set3", cut=1)

ax.set(ylabel='students')
ax.set(yticklabels=['a', 'b', 'c', 'd'])
matplotlib.pyplot.tight_layout()
sns.despine(offset=10, trim=True)

# %%
fig3, axes = matplotlib.pyplot.subplots(2, 3, figsize=(14, 8), sharex=True)

ax=sns.distplot(data['Q1'], hist=True, bins=8, kde=False, norm_hist=False, color="b", ax=axes[0,0])
sns.distplot(data['Q2'], hist=True, bins=8, kde=False, norm_hist=False, color="b", ax=axes[0,1])

sns.distplot(data['Q3'], hist=True, bins=8, kde=False, norm_hist=False, color="b", ax=axes[0,2])
sns.distplot(data['Q4'], hist=True, bins=8, kde=False, norm_hist=False, color="b", ax=axes[1,0])

sns.distplot(data['Q5'], hist=True, bins=8, kde=False, norm_hist=False, color="b", ax=axes[1,1])
sns.distplot(data['Q6'], hist=True, bins=8, kde=False, norm_hist=False, color="b", ax=axes[1,2])

ax.set(ylabel='students')
ax.set(xticklabels=['a', 'b', 'c', 'd'])
matplotlib.pyplot.tight_layout()
sns.despine(offset=10, trim=True)
