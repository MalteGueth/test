# %% [markdown]
# # Notebook for visualizing quiz results (1/27/20)
# ## first recitation, Intro to Neuroscience Spring 2020

# %%
import pandas as pd
import seaborn as sns
import matplotlib

# %% [markdown]
# ### Create pandas dataframe with column names for quiz data

# %%
file = '/Users/maltegueth/Documents/quiz_scores.csv'
columns = ['student', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'score']
data = pd.read_csv(file, sep=',', names=columns)

# %% [markdown]
# ### The correct key is: d a c a a d or 4 1 3 1 1 4

# %%
data
# Out:
#     student  Q1  Q2  Q3  Q4  Q5  Q6  score
# 0         1   4   1   3   1   1   1   0.83
# 1         2   4   1   3   1   1   4   1.00
# 2         3   4   1   3   1   1   4   1.00
# 3         4   4   1   3   1   1   4   1.00
# 4         5   4   4   3   1   1   4   0.67
# 5         6   3   1   3   1   1   4   0.83
# 6         7   4   1   3   1   1   4   1.00
# 7         8   4   1   3   1   1   4   1.00
# 8         9   4   1   3   1   1   4   1.00
# 9        10   1   1   3   1   1   4   0.83
# 10       11   4   1   3   1   1   4   1.00
# 11       12   4   1   3   1   1   4   0.83
# 12       13   4   1   2   1   1   4   0.83
# 13       14   1   2   2   1   1   4   0.50
# 14       15   4   1   3   2   1   2   0.67
# 15       16   4   1   3   1   1   4   1.00
# 16       17   3   1   3   1   1   4   0.83
# 17       18   3   1   3   1   1   4   0.83
# 18       19   4   1   3   1   1   4   1.00
# 19       20   4   1   3   1   1   4   1.00
# 20       21   3   1   3   1   1   4   0.83
# ...

# %% [markdown]
# ## Here are some basic stats from the dataframe (mean, median, sd)

# %%
data.score.mean()*100
# Out:
# 82.6969696969697

# %%
data.score.median()*100
# Out:
# 83.0

# %%
data.score.std()*100
# Out:
# 15.822224970916796

# %% [markdown]
# ## Next, check some distributional plots to visualize how the class as a whole scored

# %% [markdown]
# ### As a reminder, here are the questions and corrects answers

# %% [markdown]
#     Which of the following statements about the cortical layers is false:
#     a) Layer IV is the major cortical input layer from other sources
#     b) Layer II contains mostly granule cells
#     c) Layer VI is called the Multiform layer
#     d) Layer IV has only few projections to other regions of the brain
#     -> see slide 7: Layer IV is the major cortical input layer from other sources**
#
#     Myelin sheaths in the central nervous system are produced by __________
#     a) oligodendrocytes
#     b) Schwann cells
#     c) astrocytes
#     d) microglia
#     -> see slide 9: CNS -> oligodendrocytes -> myelination
#
#     The three main types of neuroglial cells that occur in the central nervous system are:
#     a) astrocytes, dendrites, radial glia
#     b) Schwann Cells, oligodendrocytes, astrocytes
#     c) radial glia, astrocytes, oligodendrocytes
#     d) astrocytes, granular cells, pyramidal cells
#     -> see slide 9: The CNS and PNS have different types of glial cells. The main types are: astrocytes, oligodendrocytes, radial glia
#
#     Glial cells are not specialized for receiving and transmitting electrical impulses; instead they serve a ________ function in the nervous system.
#     a) support
#     b) excitation
#     c) inhibition
#     d) amplification
#     -> see slide 10: Glial cells act as structural, biochemical and other support cells for the CNS and PNS.
#
#     The parts of the neuron that are specialized for receiving inputs are the:
#     a) dendrites
#     b) axon
#     c) cell body
#     d) terminal bouton
#     -> see slide 15: The dendrites are the input region of a neuron, that receive incoming connections from other neurons.
#     Which of the following statements is correct?
#     a) The Primary Auditory Cortex is located in the occipital lobe
#     b) The Primary Motor Cortex is separated from the Primary Somatosensory Cortex by the Sylvian Fissure
#     c) The Primary Visual Cortex is located in the frontal lobe
#     d) The Primary Somatosensory Cortex processes sensations like touch, pressure, pain or temperature
#     -> see slide 8: The Primary Somatosensory Cortex (SI) processes the sensory inputs that come from all over the body including touch, pressure, pain, temperature etc.

# %%
font = {'family' : 'Sans',
        'weight' : 'normal',
        'size'   : 18}

matplotlib.rc('font', **font)

# %%
fig1, axes = matplotlib.pyplot.subplots(2, 2, figsize=(7, 7), sharex=True)

ax = sns.distplot(data['score'], kde=False, color="b", ax=axes[0,0])
sns.distplot(data['score'], hist=False, rug=True, color="r", ax=axes[0, 1])
sns.distplot(data['score'], hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])
sns.distplot(data['score'], color="m", ax=axes[1, 1])

ax.set(ylabel='students')
matplotlib.pyplot.tight_layout()

# %%
fig2, axes = matplotlib.pyplot.subplots(figsize=(14, 6), sharex=True)

ax = sns.violinplot(data=data.loc[:, "Q1":"Q6"], palette="Set3", cut=1)

ax.set(ylabel='students')
matplotlib.pyplot.tight_layout()

# %%
fig3, axes = matplotlib.pyplot.subplots(2, 3, figsize=(14, 8), sharex=True)

ax=sns.distplot(data['Q1'], hist=True, bins=8, kde=False, norm_hist=False, color="b", ax=axes[0,0])
sns.distplot(data['Q2'], hist=True, bins=8, kde=False, norm_hist=False, color="b", ax=axes[0,1])

sns.distplot(data['Q3'], hist=True, bins=8, kde=False, norm_hist=False, color="b", ax=axes[0,2])
sns.distplot(data['Q4'], hist=True, bins=8, kde=False, norm_hist=False, color="b", ax=axes[1,0])

sns.distplot(data['Q5'], hist=True, bins=8, kde=False, norm_hist=False, color="b", ax=axes[1,1])
sns.distplot(data['Q6'], hist=True, bins=8, kde=False, norm_hist=False, color="b", ax=axes[1,2])

ax.set(ylabel='students')
matplotlib.pyplot.tight_layout()
